# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
# for matplotlib
def plot_pareto_frontier(Xs, Ys, maxX=True, maxY=True):
    '''Pareto frontier selection process'''
    sorted_list = sorted([[Xs[i], Ys[i]] for i in range(len(Xs))], reverse=maxY)
    pareto_front = [sorted_list[0]]
    for pair in sorted_list[1:]:
        if maxY:
            if pair[1] >= pareto_front[-1][1]:
                pareto_front.append(pair)
        else:
            if pair[1] <= pareto_front[-1][1]:
                pareto_front.append(pair)
    
    '''Plotting process'''
    plt.scatter(Xs,Ys)
    pf_X = [pair[0] for pair in pareto_front]
    pf_Y = [pair[1] for pair in pareto_front]
    plt.plot(pf_X, pf_Y)
    plt.xlabel("Objective 1")
    plt.ylabel("Objective 2")
    plt.show()

# %%
#for plotly

def plot_pareto_frontier2(Xs, Ys, maxX=True, maxY=True):
    '''Pareto frontier selection process'''
    sorted_list = sorted([[Xs[i], Ys[i]] for i in range(len(Xs))], reverse=maxY)
    pareto_front = [sorted_list[0]]
    for pair in sorted_list[1:]:
        if maxY:
            if pair[1] >= pareto_front[-1][1]:
                pareto_front.append(pair)
        else:
            if pair[1] <= pareto_front[-1][1]:
                pareto_front.append(pair)
    
    '''Plotting process'''
    # print(len(Xs))
    # print(np.shape(Xs))
    # print(len(Ys))
    # print(np.shape(Ys))
    fig = px.scatter(x = Xs[:,0],y= Ys[:,0])
    pf_X = [pair[0][0] for pair in pareto_front]
    pf_Y = [pair[1][0] for pair in pareto_front]
    x_list = list(pf_X)
    y_list = list(pf_Y)
    print(type(pareto_front))

    print(pareto_front)
    print(pareto_front[0][0])
    print(pareto_front[1][0])
    print(pf_X)
    # print(type(pf_X))
    # print(type(x_list))
    # print(np.shape(x_list))
    # print(len(x_list))
    
    # print(x_list[2])
    # print(Xs)
    x_list1 = []
    y_list1 = []
    for i in range(len(x_list)):
        x_list1.append(x_list[i])
        y_list1.append(y_list[i])
    # print('x list 1', x_list1)
    fig.add_trace(go.Scatter(x=pf_X, y=pf_Y))
    fig2 = px.scatter(x = pf_X,y= pf_Y)
    fig.show()
    fig2.show()

# %%
x = np.random.rand(500,1)
y = np.random.rand(500,1)

x1 = []
y1 = []
for i in range(len(x)):
    x1.append(x[i]**4 + y[i]**4 + x[i]*y[i] - (x[i]*y[i])**2 - 10*y[i]**2)
    y1.append(x[i]**4 + y[i]**4 + x[i]*y[i] - (x[i]*y[i])**2)

# %%
plot_pareto_frontier(x1,y1)

# %%
plot_pareto_frontier2(x,y)
# Out:
# <class 'list'>
# [[array([0.99858146]), array([0.35987263])], [array([0.99061496]), array([0.94988985])], [array([0.93440824]), array([0.97683561])], [array([0.82724175]), array([0.9825273])], [array([0.17446457]), array([0.99238093])]]
# [0.99858146]
# [0.99061496]
# [0.9985814623611345, 0.9906149572662633, 0.9344082365028346, 0.82724174644287, 0.17446457073223376]
# ...
